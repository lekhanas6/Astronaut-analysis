# %% [markdown]
# <a href="https://colab.research.google.com/github/lekhanas6/Astronaut-analysis/blob/main/Astronaut_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#--- Import Pandas ---
import pandas as pd
#--- Read in dataset ----
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/nasa.csv')

#--- Inspect data ---
df.head()
# Out:
#                   Name  Year  GroupNum    Status  Birth_Date     Birth_Place  \
# 0  Alan B. Shepard Jr.  1959         1  Deceased  18-11-1923  East Derry, NH
# 1   Alan G. Poindexter  1998        17  Deceased  05-11-1961    Pasadena, CA
# 2         Alan L. Bean  1963         3  Deceased  15-03-1932     Wheeler, TX
# 3     Albert Sacco Jr.  1963         3   Retired  03-05-1949      Boston, MA
# 4     Alfred M. Worden  1966         5   Retired  07-02-1932     Jackson, MI
#
#   Gender                                         Alma_Mater  \
# 0   Male                                   US Naval Academy
# 1   Male  Georgia Institute of Technology; US Naval Post...
# 2   Male                                University of Texas
# 3   Male                       Northeastern University; MIT
# 4   Male        US Military Academy; University of Michigan
#
#         Undergraduate_Major                            Graduate_Major  \
# ...

# %%
null_values = df.isnull().sum()

#--- Inspect data ---
null_values
# Out:
# Name                     0
# Year                     0
# GroupNum                 0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major      0
# Graduate_Major           0
# Military_Rank            0
# Military_Branch          0
# Space_Flights            0
# Space_Flight_hr          0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                 0
# Death_Date             303
# Death_Mission          309
# dtype: int64

# %%
df.dropna(subset=['Alma_Mater'], inplace=True)
filtered_rows = df[(df['Death_Mission'].isnull()) & (~df['Death_Date'].isnull())]
rows_to_drop = filtered_rows.index
df.drop(rows_to_drop, inplace=True)
df['Birth_Date'] = pd.to_datetime(df['Birth_Date'], dayfirst=True)

df['Death_Date'] = pd.to_datetime(df['Death_Date'], dayfirst=True)

df
# Out:
#                         Name  Year  GroupNum      Status Birth_Date  \
# 0        Alan B. Shepard Jr.  1959         1    Deceased 1923-11-18
# 1         Alan G. Poindexter  1998        17    Deceased 1961-11-05
# 2               Alan L. Bean  1963         3    Deceased 1932-03-15
# 3           Albert Sacco Jr.  1963         3     Retired 1949-05-03
# 4           Alfred M. Worden  1966         5     Retired 1932-02-07
# ..                       ...   ...       ...         ...        ...
# 352      William M. Shepherd  1984        10     Retired 1949-07-26
# 353         William R. Pogue  1966         5     Retired 1930-01-23
# 354  William S. McArthur Jr.  1990         3  Management 1951-07-26
# 355         Winston E. Scott  1992        14     Retired 1950-08-06
# 356          Yvonne D. Cagle  1996        16  Management 1959-04-24
#
#         Birth_Place  Gender  \
# 0    East Derry, NH    Male
# 1      Pasadena, CA    Male
# 2       Wheeler, TX    Male
# 3        Boston, MA    Male
# ...

# %%
#export the cleaned data
df.to_csv('astronauts.csv', index=False)
